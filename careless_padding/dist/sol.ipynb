# %%
from pwn import *
from string import printable, ascii_lowercase, ascii_uppercase, digits
HOST = 'chal-careless-padding.chal.hitconctf.com'
HOST = 'localhost'
PORT = '11111'

DICTIONARY = ascii_lowercase + digits + '_!?}' + ascii_uppercase

r = remote(HOST, PORT)
print(r.recvuntil(b's your encrypted key: '))
key = bytes.fromhex(r.recvline().decode().strip())
r.recv()
IV = key[:16]
CT = key[16:]

def get_blocks(data: bytes, bs: int = 16) -> list:
    return [data[i:i+bs] for i in range(0, len(data), bs)]

def xor(a: bytes, b: bytes, repeat = True) -> bytes:
    '''
        to get the key to roll over, the module operator
        is used over the length of the key, 
        so string_pos MOD key_length
        ex: 0%3 = 0, 1%3 = 1, 2%3 = 2, 3%3 = 0, etc..
    '''
    xored = []
    if repeat:
        for char_pos, c in enumerate(a):
            xored.append(c ^ b[char_pos%len(b)])
    else:
        if len(a)<len(b):
            b, a = a, b
        for char_pos in range(len(b)):
            xored.append(a[char_pos] ^ b[char_pos])
        for char_pos in range(len(b), len(a)):
            xored.append(a[char_pos])
    return bytes(xored)


def bit_flip(previous_block: bytes, guess: int, flip_pos: int, padding_byte: int) -> bytes:
    flipped_byte = bytes([previous_block[flip_pos] ^ guess ^ padding_byte])
    return previous_block[:flip_pos] + flipped_byte + previous_block[flip_pos+1:]

def send_msg(r, ciphertext: bytes) -> str:
    payload = ciphertext.hex()
    r.sendline(payload)
    response = r.recvline().decode().strip()
    print(response)
    response = r.recv().decode().strip()
    print(response)
    return response


def get_padding_size(r, ciphertext: bytes):
    ct_blocks = get_blocks(ciphertext)[-2:]
    # ct_blocks[0] = b'R\xd5\x0bx\xcb\xec\x1b\xf4\xb9k\x84\x07\xa4_\xa3\xb9'
    for byte in range(16):
        # print(f"position: {byte}")
        ct_blocks[0] = bit_flip(ct_blocks[0], guess=b'}'[0], flip_pos=byte, padding_byte=1)
        iv_to_send = ct_blocks[0]
        ct_to_send = b''.join(ct_blocks[1:])
        response = send_msg(r, b''.join([iv_to_send, ct_to_send]))
        # print(response)
        if 'put that weirdo in me' in response:
            return 16-byte-1

def get_padding_byte(r, ciphertext: bytes, padding_size):
    for byte in printable:
        byte = ord(byte)
        # print(f'guessing byte: {bytes([byte])}')
        ct_blocks = get_blocks(ciphertext)[-2:]
        ct_blocks[0] = bit_flip(ct_blocks[0], guess=b'}'[0], flip_pos=15-padding_size, padding_byte=15-padding_size-2)
        ct_blocks[0] = bit_flip(ct_blocks[0], guess=b'}'[0], flip_pos=15-padding_size-2, padding_byte=byte)
        ct_to_send = b''.join(ct_blocks[1:])
        iv = ct_blocks[0]
        response = send_msg(r, b''.join([iv, ct_to_send]))
        if 'Bad key' in response:
            return byte

def recover_block(r, ciphertext: bytes, padding_size, padding_byte):
    known = b''
    for position in range(3):
        for byte in printable:
            byte = ord(byte)
            # print(f'guessing byte: {bytes([byte])}')
            ct_blocks = get_blocks(ciphertext)[-2:]
            ct_blocks[0] = bit_flip(ct_blocks[0], guess=b'}'[0], flip_pos=15-padding_size, padding_byte=position)
            ct_blocks[0] = bit_flip(ct_blocks[0], guess=b'}'[0], flip_pos=15-padding_size-2, padding_byte=padding_byte)
            ct_blocks[0] = bit_flip(ct_blocks[0], guess=byte, flip_pos=position, padding_byte=padding_byte)

            ct_to_send = b''.join(ct_blocks[1:])
            iv = ct_blocks[0]
            response = send_msg(r, b''.join([iv, ct_to_send]))
            if 'Bad key' in response:
                known += bytes([byte])
                # print(f'known: {known}')
                # print('_'*50)
                break
            else:
                # print(response)
                pass
    return known

def check_if_padding_valid(previous_block, current_block):
    ct_to_send = current_block
    iv = previous_block
    response = send_msg(r, b''.join([iv, ct_to_send]))
    if 'Bad key' in response:
        return True
    return False

def get_block_offending_byte(iv, ciphertexts):
    padding_valid = check_if_padding_valid(iv, ciphertexts)
    if padding_valid:
        return 128
    else:
        for byte in range(256):
            iv_new = iv
            for i in range(16):
                iv_new = bit_flip(iv_new, guess=byte, flip_pos=i, padding_byte=0)
            ct_to_send = ciphertexts
            response = send_msg(r, b''.join([iv_new, ct_to_send]))
            if 'Bad key' in response:
                print(f"found offending byte: {bytes([byte])}")
                print('_'*50)
                return byte
        
def get_block_15th_byte_candidates(iv, ciphertexts, offending_byte, known_plaintext):
    candidates = []
    if check_if_padding_valid(iv, ciphertexts):
        for i in range(16):
            iv_new = bit_flip(iv, guess=offending_byte, flip_pos=i, padding_byte=0)
            ct_to_send = ciphertexts
            response = send_msg(r, b''.join([iv_new, ct_to_send]))
            if 'Bad key' not in response:
                print(f"found position: {i}")
                print('_'*50)
                last_byte = known_plaintext[i]
                for character in printable:
                        if ord(character) % 16 == i:
                            candidates.append(character)
                return candidates, last_byte
            
    for i in range(16):
        iv_new = bit_flip(iv, guess=offending_byte, flip_pos=i, padding_byte=0)
        ct_to_send = ciphertexts
        response = send_msg(r, b''.join([iv_new, ct_to_send]))
        if 'Bad key' in response:
            print(f"found position: {i}")
            print('_'*50)
            last_byte = known_plaintext[i] ^ offending_byte
            for character in printable:
                    if ord(character) % 16 == i:
                        candidates.append(character)
            return candidates, last_byte


# def recover_block(iv, ciphertext, known_previous_block):
#     known_block_dict = {x:None for x in range(16)}
#     # get last byte
#     if check_if_padding_valid(iv, ciphertext):
#         candidates, last_byte = get_block_15th_byte_candidates(iv, ciphertext, 128, known_previous_block)
#     else:
#         candidates, last_byte = get_block_15th_byte_candidates(iv, ciphertext, get_block_offending_byte(iv, ciphertext), known_previous_block)
#     known_block_dict[15] = [chr(last_byte), chr(last_byte ^ 1)]
#     known_block_dict[14] = candidates

#     for pos in reversed(range(14)):
#         print(known_block_dict)
#         known_text = ''.join([x[0] for x in known_block_dict.values() if x is not None])
#         known_block_dict[pos] = get_character(ciphertext[:16], ciphertext[16:], known_text, pos)
#     return known_block_dict

def recover_block(iv, ciphertext, known_previous_block):
    known_block_dict = {x:None for x in range(16)}
    known_block_confirmed = ''
    # get last byte
    if check_if_padding_valid(iv, ciphertext):
        candidates, last_byte = get_block_15th_byte_candidates(iv, ciphertext, 128, known_previous_block)
    else:
        candidates, last_byte = get_block_15th_byte_candidates(iv, ciphertext, get_block_offending_byte(iv, ciphertext), known_previous_block)
    known_block_dict[15] = [chr(last_byte), chr(last_byte ^ 1)]
    known_block_dict[14] = candidates
    known_block_confirmed = chr(last_byte ^ 1) + known_block_confirmed
    confirmed_byte = confirm_byte(ciphertext[:16], ciphertext[16:], known_block_confirmed, candidates)
    known_block_confirmed = confirmed_byte + known_block_confirmed

    for pos in reversed(range(14)):
        print(known_block_dict)
        print("#"*50)
        print(f"confirmed flag chars = {known_block_confirmed}")
        print("#"*50)
        known_text = ''.join([x[0] for x in known_block_dict.values() if x is not None])
        known_block_dict[pos] = get_character(ciphertext[:16], ciphertext[16:], known_text, pos)
        confirmed_byte = confirm_byte(ciphertext[:16], ciphertext[16:], known_block_confirmed, known_block_dict[pos])
        known_block_confirmed = confirmed_byte + known_block_confirmed
    return known_block_dict

def get_chars_for_pos(pos: int):
    candidates = []
    for character in printable:
        if ord(character)%16 == pos:
            candidates.append(character)
    return candidates

def get_character(iv, ciphertexts, known_plaintext, pos):
    iv_new_orig = iv
    candidates = []
    iv_new_orig = bit_flip(iv_new_orig, guess=ord(known_plaintext[-1]), flip_pos=15, padding_byte=b'{'[0])
    chars_for_pos = get_chars_for_pos(pos)
    for character in printable:
        print(f"trying character: {character}")
        iv_new = bit_flip(iv_new_orig, guess=ord(known_plaintext[-2]), flip_pos=14, padding_byte=ord(chars_for_pos[0]))
        iv_new = bit_flip(iv_new, guess=ord(character), flip_pos=pos, padding_byte=b'{'[0])
        ct_to_send = ciphertexts
        iv = iv_new
        response = send_msg(r, b''.join([iv, ct_to_send]))
        if 'Bad key' in response:
            candidates.append(character)
            if len(candidates) == 2:
                return candidates
    return candidates

def confirm_byte(iv, ciphertext, known_text, candidates):
    print(f"attempting to confirm: {candidates}")
    len_known = len(known_text)
    iv_new_orig = iv
    for i in range(len_known):
        iv_new_orig = bit_flip(iv_new_orig, guess=ord(known_text[-i-1]), flip_pos=15-i, padding_byte=b'{'[0])
    for candidate in candidates:
        print(f"trying candidate: {candidate}")
        success = True
        for check in range(len_known):
            position_byte = get_chars_for_pos(15-check)[0]
            iv_new = bit_flip(iv_new_orig, guess=ord(candidate), flip_pos=15-len_known, padding_byte=ord(position_byte))
            response = send_msg(r, b''.join([iv_new, ciphertext]))
            if 'Bad key' not in response:
                success = False
        if success and len_known > 1:
            iv_new_orig = iv
            iv_new_orig = bit_flip(iv_new_orig, guess=ord(known_text[-i-1]), flip_pos=15, padding_byte=ord(candidate))
            position_byte = get_chars_for_pos(15-len_known)[0]
            iv_new_orig = bit_flip(iv_new_orig, guess=ord(candidate), flip_pos=14, padding_byte=ord(position_byte))
            response = send_msg(r, b''.join([iv_new_orig, ciphertext]))
            if 'Bad key' in response:
                return candidate
        elif success:
            return candidate

# block before last
"""
{0: ['b', 'c'],
 1: ['0', '1'],
 2: ['2', '3'],
 3: ['^', '_'],
 4: ['6', '7'],
 5: ['0', '1'],
 6: ['6', '7'],
 7: ['a', '`'],
 8: ['a', '`'],
 9: ['6', '7'],
 10: ['8', '9'],
 11: ['b', 'c'],
 12: ['0', '1'],
 13: ['6', '7'],
 14: ['4', 'd', 't', 'D', 'T', '$'],
 15: ['7', '6']}
"""
# last block
"""
{0: ['a', '`'],
 1: ['b', 'c'],
 2: ['8', '9'],
 3: ['0', '1'],
 4: ['f', 'g'],
 5: ['4', '5'],
 6: ['6', '7'],
 7: ['d', 'e'],
 8: ['0', '1'],
 9: ['8', '9'],
 10: ['6', '7'],
 11: ['8', '9'],
 12: ['d', 'e'],
 13: ['8', '9'],
 14: ['5', 'e', 'u', 'E', 'U', '%'],
 15: ['8', '9']}

"""
known_blocks = [b'{"key": "hitcon{', b'p4dd1ng_w0n7_s4v', b'3_y0u_Fr0m_4_0ra', b'c13_606aa68b0647']
known_blocks = [b'{"key": "hitcon{']
for block, known_block in enumerate(known_blocks):
    new_block = recover_block(key[16*(block):16*(block+1)], key[16*(block+1):16*(block+3)], known_block)
    print(new_block)
# Out:
# [x] Opening connection to localhost on port 11111
# [x] Opening connection to localhost on port 11111: Trying ::1
# [+] Opening connection to localhost on port 11111: Done
# b'b\'{"key": "hitcon{p4dd1ng_w0n7_s4v3_y0u_Fr0m_4_0rac13_617aa68c06d7ab91f57d1969e8e8532}"}\'\nb\'{"key": "hitcon{p4dd1ng_w0n7_s4v3_y0u_Fr0m_4_0rac13_617aa68c06d7ab91f57d1969e8e8532}"}8888888888\'\n\n*********************************************************\nYou are put into the careless prison and trying to escape.\nThanksfully, someone forged a key for you, but seems like it\'s encrypted... \nFortunately they also leave you a copied (and apparently alive) prison door.\nThe replica pairs with this encrypted key. Wait, how are this suppose to help?\nAnyway, here\'s your encrypted key: '
# [b'{"key": "hitcon{', b'p4dd1ng_w0n7_s4v']
# message_len: 31, X: 4, Y: v
# _Y location: 4
# _Y: b'y'
# _Y^1: b'x'
# Y: b'v'
# Don't put that weirdo in me!
# Try unlock:
# [b'{"key": "hitcon{', b'p4dd1ng_w0n7_s4v']
# message_len: 31, X: 4, Y: v
# _Y location: 4
# _Y: b'y'
# _Y^1: b'x'
# Y: b'v'
# Don't put that weirdo in me!
# Try unlock:
# [b'{"key": "hitcon{', b'p4dd1ng_w0n7_s4v']
# message_len: 31, X: 4, Y: v
# _Y location: 4
# _Y: b'y'
# _Y^1: b'x'
# Y: b'v'
# Don't put that weirdo in me!
# Try unlock:
# [b'z#jdx#;!#ihubnoz', b'p4dd1ng_w0n7_s4v']
# message_len: 31, X: 4, Y: v
# _Y location: 4
# _Y: b'x'
# _Y^1: b'y'
# Y: b'v'
# Don't put that weirdo in me!
# Try unlock:
# [b'y ig{ 8" jkvamly', b'p4dd1ng_w0n7_s4v']
# message_len: 31, X: 4, Y: v
# _Y location: 4
# _Y: b'{'
# _Y^1: b'z'
# Y: b'v'
# Don't put that weirdo in me!
# Try unlock:
# [b'x!hfz!9#!kjw`lmx', b'p4dd1ng_w0n7_s4v']
# message_len: 31, X: 4, Y: v
# _Y location: 4
# _Y: b'z'
# _Y^1: b'{'
# Y: b'v'
# Don't put that weirdo in me!
# Try unlock:
# [b'\x7f&oa}&>$&lmpgkj\x7f', b'p4dd1ng_w0n7_s4v']
# message_len: 31, X: 4, Y: v
# _Y location: 4
# _Y: b'}'
# _Y^1: b'|'
# Y: b'v'
# Don't put that weirdo in me!
# Try unlock:
# [b"~'n`|'?%'mlqfjk~", b'p4dd1ng_w0n7_s4v']
# message_len: 31, X: 4, Y: v
# _Y location: 4
# _Y: b'|'
# _Y^1: b'}'
# Y: b'v'
# Don't put that weirdo in me!
# Try unlock:
# [b'}$mc\x7f$<&$noreih}', b'p4dd1ng_w0n7_s4v']
# message_len: 31, X: 4, Y: v
# _Y location: 4
# _Y: b'\x7f'
# _Y^1: b'~'
# Y: b'v'
# Don't put that weirdo in me!
# Try unlock:
# [b"|%lb~%='%onsdhi|", b'p4dd1ng_w0n7_s4v']
# message_len: 31, X: 4, Y: v
# _Y location: 4
# _Y: b'~'
# _Y^1: b'\x7f'
# Y: b'v'
# Don't put that weirdo in me!
# Try unlock:
# [b's*cmq*2(*`a|kgfs', b'p4dd1ng_w0n7_s4v']
# message_len: 31, X: 4, Y: v
# _Y location: 4
# _Y: b'q'
# _Y^1: b'p'
# Y: b'v'
# Don't put that weirdo in me!
# Try unlock:
# [b'r+blp+3)+a`}jfgr', b'p4dd1ng_w0n7_s4v']
# message_len: 31, X: 4, Y: v
# _Y location: 4
# _Y: b'p'
# _Y^1: b'q'
# Y: b'v'
# Don't put that weirdo in me!
# Try unlock:
# [b'q(aos(0*(bc~iedq', b'p4dd1ng_w0n7_s4v']
# message_len: 31, X: 4, Y: v
# _Y location: 4
# _Y: b's'
# _Y^1: b'r'
# Y: b'v'
# Don't put that weirdo in me!
# Try unlock:
# [b'p)`nr)1+)cb\x7fhdep', b'p4dd1ng_w0n7_s4v']
# message_len: 31, X: 4, Y: v
# _Y location: 4
# _Y: b'r'
# _Y^1: b's'
# Y: b'v'
# Don't put that weirdo in me!
# Try unlock:
# [b'w.giu.6,.dexocbw', b'p4dd1ng_w0n7_s4v']
# message_len: 31, X: 4, Y: v
# _Y location: 4
# _Y: b'u'
# _Y^1: b't'
# Y: b'v'
# Don't put that weirdo in me!
# Try unlock:
# [b'v/fht/7-/edynbcv', b'p4dd1ng_w0n7_s4v']
# message_len: 31, X: 4, Y: v
# _Y location: 4
# _Y: b't'
# _Y^1: b'u'
# Y: b'v'
# Don't put that weirdo in me!
# Try unlock:
# [b'u,ekw,4.,fgzma`u', b'p4dd1ng_w0n7_s4v']
# message_len: 31, X: 4, Y: v
# _Y location: 4
# _Y: b'w'
# _Y^1: b'v'
# Y: b'v'
# Bad key... do you even try?
# Try unlock:
# found offending byte: b'\x0e'
# __________________________________________________
# [b'{"key": "hitcon{', b'p4dd1ng_w0n7_s4v']
# message_len: 31, X: 4, Y: v
# _Y location: 4
# _Y: b'y'
# _Y^1: b'x'
# Y: b'v'
# Don't put that weirdo in me!
# Try unlock:
# [b'u"key": "hitcon{', b'p4dd1ng_w0n7_s4v']
# message_len: 31, X: 4, Y: v
# _Y location: 4
# _Y: b'y'
# _Y^1: b'x'
# Y: b'v'
# Don't put that weirdo in me!
# Try unlock:
# [b'{,key": "hitcon{', b'p4dd1ng_w0n7_s4v']
# message_len: 31, X: 4, Y: v
# _Y location: 4
# _Y: b'y'
# _Y^1: b'x'
# Y: b'v'
# Don't put that weirdo in me!
# Try unlock:
# [b'{"eey": "hitcon{', b'p4dd1ng_w0n7_s4v']
# message_len: 31, X: 4, Y: v
# _Y location: 4
# _Y: b'y'
# _Y^1: b'x'
# Y: b'v'
# Don't put that weirdo in me!
# Try unlock:
# [b'{"kky": "hitcon{', b'p4dd1ng_w0n7_s4v']
# message_len: 31, X: 4, Y: v
# _Y location: 4
# _Y: b'y'
# _Y^1: b'x'
# Y: b'v'
# Don't put that weirdo in me!
# Try unlock:
# [b'{"kew": "hitcon{', b'p4dd1ng_w0n7_s4v']
# message_len: 31, X: 4, Y: v
# _Y location: 4
# _Y: b'w'
# _Y^1: b'v'
# Y: b'v'
# Bad key... do you even try?
# Try unlock:
# found position: 4
# __________________________________________________
# attempting to confirm: ['4', 'd', 't', 'D', 'T', '$']
# trying candidate: 4
# [b'p4dd1ng_w0n7_so{']
# message_len: 15, X: o, Y: {
# _Y location: -1
# _Y: b'{'
# _Y^1: b'z'
# Y: b'{'
# Bad key... do you even try?
# Try unlock:
# {0: None, 1: None, 2: None, 3: None, 4: None, 5: None, 6: None, 7: None, 8: None, 9: None, 10: None, 11: None, 12: None, 13: None, 14: ['4', 'd', 't', 'D', 'T', '$'], 15: ['w', 'v']}
# ##################################################
# confirmed flag chars = 4v
# ##################################################
# trying character: 0
# [b'p4dd1ng_w0n7_8mz']
# message_len: 15, X: m, Y: z
# _Y location: -3
# _Y: b'8'
# _Y^1: b'9'
# Y: b'z'
# Don't put that weirdo in me!
# Try unlock:
# trying character: 1
# [b'p4dd1ng_w0n7_9mz']
# message_len: 15, X: m, Y: z
# _Y location: -3
# _Y: b'9'
# _Y^1: b'8'
# Y: b'z'
# Don't put that weirdo in me!
# Try unlock:
# trying character: 2
# [b'p4dd1ng_w0n7_:mz']
# message_len: 15, X: m, Y: z
# _Y location: -3
# _Y: b':'
# _Y^1: b';'
# Y: b'z'
# Don't put that weirdo in me!
# Try unlock:
# trying character: 3
# [b'p4dd1ng_w0n7_;mz']
# message_len: 15, X: m, Y: z
# _Y location: -3
# _Y: b';'
# _Y^1: b':'
# Y: b'z'
# Don't put that weirdo in me!
# Try unlock:
# trying character: 4
# [b'p4dd1ng_w0n7_<mz']
# message_len: 15, X: m, Y: z
# _Y location: -3
# _Y: b'<'
# _Y^1: b'='
# Y: b'z'
# Don't put that weirdo in me!
# Try unlock:
# trying character: 5
# [b'p4dd1ng_w0n7_=mz']
# message_len: 15, X: m, Y: z
# _Y location: -3
# _Y: b'='
# _Y^1: b'<'
# Y: b'z'
# Don't put that weirdo in me!
# Try unlock:
# trying character: 6
# [b'p4dd1ng_w0n7_>mz']
# message_len: 15, X: m, Y: z
# _Y location: -3
# _Y: b'>'
# _Y^1: b'?'
# Y: b'z'
# Don't put that weirdo in me!
# Try unlock:
# trying character: 7
# [b'p4dd1ng_w0n7_?mz']
# message_len: 15, X: m, Y: z
# _Y location: -3
# _Y: b'?'
# _Y^1: b'>'
# Y: b'z'
# Don't put that weirdo in me!
# Try unlock:
# trying character: 8
# [b'p4dd1ng_w0n7_0mz']
# message_len: 15, X: m, Y: z
# _Y location: -3
# _Y: b'0'
# _Y^1: b'1'
# Y: b'z'
# Don't put that weirdo in me!
# Try unlock:
# trying character: 9
# [b'p4dd1ng_w0n7_1mz']
# message_len: 15, X: m, Y: z
# _Y location: -3
# _Y: b'1'
# _Y^1: b'0'
# Y: b'z'
# Don't put that weirdo in me!
# Try unlock:
# trying character: a
# [b'p4dd1ng_w0n7_imz']
# message_len: 15, X: m, Y: z
# _Y location: -3
# _Y: b'i'
# _Y^1: b'h'
# Y: b'z'
# Don't put that weirdo in me!
# Try unlock:
# trying character: b
# [b'p4dd1ng_w0n7_jmz']
# message_len: 15, X: m, Y: z
# _Y location: -3
# _Y: b'j'
# _Y^1: b'k'
# Y: b'z'
# Don't put that weirdo in me!
# Try unlock:
# trying character: c
# [b'p4dd1ng_w0n7_kmz']
# message_len: 15, X: m, Y: z
# _Y location: -3
# _Y: b'k'
# _Y^1: b'j'
# Y: b'z'
# Don't put that weirdo in me!
# Try unlock:
# trying character: d
# [b'p4dd1ng_w0n7_lmz']
# message_len: 15, X: m, Y: z
# _Y location: -3
# _Y: b'l'
# _Y^1: b'm'
# Y: b'z'
# Don't put that weirdo in me!
# Try unlock:
# trying character: e
# [b'p4dd1ng_w0n7_mmz']
# message_len: 15, X: m, Y: z
# _Y location: -3
# _Y: b'm'
# _Y^1: b'l'
# Y: b'z'
# Don't put that weirdo in me!
# Try unlock:
# trying character: f
# [b'p4dd1ng_w0n7_nmz']
# message_len: 15, X: m, Y: z
# _Y location: -3
# _Y: b'n'
# _Y^1: b'o'
# Y: b'z'
# Don't put that weirdo in me!
# Try unlock:
# trying character: g
# [b'p4dd1ng_w0n7_omz']
# message_len: 15, X: m, Y: z
# _Y location: -3
# _Y: b'o'
# _Y^1: b'n'
# Y: b'z'
# Don't put that weirdo in me!
# Try unlock:
# trying character: h
# [b'p4dd1ng_w0n7_`mz']
# message_len: 15, X: m, Y: z
# _Y location: -3
# _Y: b'`'
# _Y^1: b'a'
# Y: b'z'
# Don't put that weirdo in me!
# Try unlock:
# trying character: i
# [b'p4dd1ng_w0n7_amz']
# message_len: 15, X: m, Y: z
# _Y location: -3
# _Y: b'a'
# _Y^1: b'`'
# Y: b'z'
# Don't put that weirdo in me!
# Try unlock:
# trying character: j
# [b'p4dd1ng_w0n7_bmz']
# message_len: 15, X: m, Y: z
# _Y location: -3
# _Y: b'b'
# _Y^1: b'c'
# Y: b'z'
# Don't put that weirdo in me!
# Try unlock:
# trying character: k
# [b'p4dd1ng_w0n7_cmz']
# message_len: 15, X: m, Y: z
# _Y location: -3
# _Y: b'c'
# _Y^1: b'b'
# Y: b'z'
# Don't put that weirdo in me!
# Try unlock:
# trying character: l
# [b'p4dd1ng_w0n7_dmz']
# message_len: 15, X: m, Y: z
# _Y location: -3
# _Y: b'd'
# _Y^1: b'e'
# Y: b'z'
# Don't put that weirdo in me!
# Try unlock:
# trying character: m
# [b'p4dd1ng_w0n7_emz']
# message_len: 15, X: m, Y: z
# _Y location: -3
# _Y: b'e'
# _Y^1: b'd'
# Y: b'z'
# Don't put that weirdo in me!
# Try unlock:
# trying character: n
# [b'p4dd1ng_w0n7_fmz']
# message_len: 15, X: m, Y: z
# _Y location: -3
# _Y: b'f'
# _Y^1: b'g'
# Y: b'z'
# Don't put that weirdo in me!
# Try unlock:
# trying character: o
# [b'p4dd1ng_w0n7_gmz']
# message_len: 15, X: m, Y: z
# _Y location: -3
# _Y: b'g'
# _Y^1: b'f'
# Y: b'z'
# Don't put that weirdo in me!
# Try unlock:
# trying character: p
# [b'p4dd1ng_w0n7_xmz']
# message_len: 15, X: m, Y: z
# _Y location: -3
# _Y: b'x'
# _Y^1: b'y'
# Y: b'z'
# Don't put that weirdo in me!
# Try unlock:
# trying character: q
# [b'p4dd1ng_w0n7_ymz']
# message_len: 15, X: m, Y: z
# _Y location: -3
# _Y: b'y'
# _Y^1: b'x'
# Y: b'z'
# Don't put that weirdo in me!
# Try unlock:
# trying character: r
# [b'p4dd1ng_w0n7_zmz']
# message_len: 15, X: m, Y: z
# _Y location: -3
# _Y: b'z'
# _Y^1: b'{'
# Y: b'z'
# Bad key... do you even try?
# Try unlock:
# trying character: s
# [b'p4dd1ng_w0n7_{mz']
# message_len: 15, X: m, Y: z
# _Y location: -3
# _Y: b'{'
# _Y^1: b'z'
# Y: b'z'
# Bad key... do you even try?
# Try unlock:
# attempting to confirm: ['r', 's']
# trying candidate: r
# [b'p4dd1ng_w0n7_n{{']
# message_len: 14, X: n, Y: {
# _Y location: -2
# _Y: b'{'
# _Y^1: b'z'
# Y: b'{'
# Bad key... do you even try?
# Try unlock:
# [b'p4dd1ng_w0n7_o{{']
# message_len: 14, X: o, Y: {
# _Y location: -1
# _Y: b'{'
# _Y^1: b'z'
# Y: b'{'
# Bad key... do you even try?
# Try unlock:
# [b'p4dd1ng_w0n7_s+0']
# message_len: 15, X: +, Y: 0
# _Y location: -5
# _Y: b'7'
# _Y^1: b'6'
# Y: b'0'
# Don't put that weirdo in me!
# Try unlock:
# trying candidate: s
# [b'p4dd1ng_w0n7_o+0']
# message_len: 15, X: +, Y: 0
# _Y location: -5
# _Y: b'7'
# _Y^1: b'6'
# Y: b'0'
# Don't put that weirdo in me!
# Try unlock:
# [b'p4dd1ng_w0n7_n+0']
# message_len: 15, X: +, Y: 0
# _Y location: -5
# _Y: b'7'
# _Y^1: b'6'
# Y: b'0'
# Don't put that weirdo in me!
# Try unlock:
# /tmp/ipykernel_50865/2191487750.py:46: BytesWarning: Text is not bytes; assuming ASCII, no guarantees. See https://docs.pwntools.com/#bytes
#   r.sendline(payload)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/io/code/ctf/cryptopals/careless_padding/dist/sol.ipynb Cell 1 line 2
#     <a href='vscode-notebook-cell:/home/io/code/ctf/cryptopals/careless_padding/dist/sol.ipynb#W0sZmlsZQ%3D%3D?line=289'>290</a> known_blocks = [b'{"key": "hitcon{']
#     <a href='vscode-notebook-cell:/home/io/code/ctf/cryptopals/careless_padding/dist/sol.ipynb#W0sZmlsZQ%3D%3D?line=290'>291</a> for block, known_block in enumerate(known_blocks):
# --> <a href='vscode-notebook-cell:/home/io/code/ctf/cryptopals/careless_padding/dist/sol.ipynb#W0sZmlsZQ%3D%3D?line=291'>292</a>     new_block = recover_block(key[16*(block):16*(block+1)], key[16*(block+1):16*(block+3)], known_block)
#     <a href='vscode-notebook-cell:/home/io/code/ctf/cryptopals/careless_padding/dist/sol.ipynb#W0sZmlsZQ%3D%3D?line=292'>293</a>     print(new_block)
#
# /home/io/code/ctf/cryptopals/careless_padding/dist/sol.ipynb Cell 1 line 1
#     <a href='vscode-notebook-cell:/home/io/code/ctf/cryptopals/careless_padding/dist/sol.ipynb#W0sZmlsZQ%3D%3D?line=193'>194</a>     known_block_dict[pos] = get_character(ciphertext[:16], ciphertext[16:], known_text, pos)
#     <a href='vscode-notebook-cell:/home/io/code/ctf/cryptopals/careless_padding/dist/sol.ipynb#W0sZmlsZQ%3D%3D?line=194'>195</a>     confirmed_byte = confirm_byte(ciphertext[:16], ciphertext[16:], known_block_confirmed, known_block_dict[pos])
# --> <a href='vscode-notebook-cell:/home/io/code/ctf/cryptopals/careless_padding/dist/sol.ipynb#W0sZmlsZQ%3D%3D?line=195'>196</a>     known_block_confirmed = confirmed_byte + known_block_confirmed
#     <a href='vscode-notebook-cell:/home/io/code/ctf/cryptopals/careless_padding/dist/sol.ipynb#W0sZmlsZQ%3D%3D?line=196'>197</a> return known_block_dict
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'str'

# %%
b'3_y0u_Fr0m_4_0rac13_707a'

# %%
get_chars_for_pos(0)
# Out:
# ['0', 'p', 'P', '@', '`', ' ']

# %%
test_dict = {x:None for x in range(16)}
test_dict[15] = ['a']
test_dict[14] = ['h','H','x','X','8']
''.join([x[0] for x in test_dict.values() if x is not None])
# Out:
# 'ha'

# %%
#!/usr/local/bin/python
import random
import os
from secret import flag
from Crypto.Cipher import AES
from Crypto.Random import get_random_bytes
import json

N = 16

# 0 -> 0, 1~N -> 1, (N+1)~(2N) -> 2 ...
def count_blocks(length):
    block_count = (length-1) // N + 1
    return block_count

def find_repeat_tail(message):
    Y = message[-1]
    message_len = len(message)
    for i in range(len(message)-1, -1, -1):
        if message[i] != Y:
            X = message[i]
            message_len = i + 1
            break
    return message_len, X, Y

def my_padding(message):
    print(message)
    message_len = len(message)
    block_count = count_blocks(message_len)
    result_len =  block_count * N
    if message_len % N == 0:
        result_len += N
    X = message[-1]
    Y = message[(block_count-2)*N+(X%N)]
    print(f'X: {bytes([X])}, Y: {bytes([Y])}')
    if X==Y:
        Y = Y^1
    print(f'X: {bytes([X])}, Y: {bytes([Y])}')
    padded = message.ljust(result_len, bytes([Y]))
    return padded

def my_unpad(message):
    message_len, X, Y = find_repeat_tail(message)
    block_count = count_blocks(message_len)
    _Y = message[(block_count-2)*N+(X%N)]
    print(f"pos: {(block_count-2)*N+(X%N)}, Y_ = {bytes([_Y])}, Y = {bytes([Y])}")
    if (Y != _Y and Y != _Y^1):
        raise ValueError("Incorrect Padding")
    return message[:message_len]
def get_blocks(data: bytes, bs: int = 16) -> list:
    return [data[i:i+bs] for i in range(0, len(data), bs)]

# message = b'a'*16*4 +b'_bcdefghijklm3zzzzzzzzzz' + b'}"}'
# X = message[-1]
# padded = my_padding(message)
# message_len = len(message)
# block_count = count_blocks(message_len)
# print(f'message_len: {message_len}, block_count: {block_count}')
# print((block_count-2)*16+(X%16))
# chr(message[(block_count-2)*16+(X%16)])

# %%
import json
def bit_flip(previous_block: bytes, guess: int, flip_pos: int, padding_byte: int) -> bytes:
    flipped_byte = bytes([previous_block[flip_pos] ^ guess ^ padding_byte])
    print(f"previous_block[flip_pos]: {bytes([previous_block[flip_pos]])}")
    return previous_block[:flip_pos] + flipped_byte + previous_block[flip_pos+1:]

k = b'YELLOW SUBMARINE'
iv = b'\x01\x02\x03\x04' * 4
# iv = os.urandom(16)
cipher = AES.new(k, AES.MODE_CBC, iv) 
message = 'hitcon{' + 'a426'*4*3 + '_-@0123486759Ab2DeF}'
message = json.dumps({'key':message}).encode()
padded = my_padding(message)
ciphertext = cipher.encrypt(padded)
print(get_blocks(padded))

# ct_blocks[0] = b'R\xd5\x0bx\xcb\xec\x1b\xf4\xb9k\x84\x07\xa4_\xa3\xb9'
def detect_padding_byte():
    for byte in range(1,256):
        print(f'guessing byte: {bytes([byte])}')
        ct_blocks = get_blocks(ciphertext)[-2:]
        ct_blocks[0] = bit_flip(ct_blocks[0], guess=b'}'[0], flip_pos=15-6, padding_byte=byte)
        # ct_blocks[0] = bytes([96]) + ct_blocks[0][1:]
        # ct_blocks[0] = bit_flip(ct_blocks[0], guess=0, flip_pos=0, padding_byte=1)
        ct_to_send = b''.join(ct_blocks[1:])
        iv = ct_blocks[0]
        cipher = AES.new(k, AES.MODE_CBC, iv)
        decrypted = cipher.decrypt(ct_to_send)
        print(f'decrypted: {get_blocks(decrypted)}')
        try:
            unpadded = my_unpad(decrypted)
            print(f'unpadded: {get_blocks(unpadded)}')
            print('_'*50)
        except:
            print('incorrect padding')
            print('_'*50)
            

# detect_padding_byte()
PADDING_SIZE = 10
PADDING_BYTE = b'A'[0]
# try to get padding byte

# known = b''
# print(f'guessing byte: {bytes([byte])}')
ct_blocks = get_blocks(ciphertext)[-3:-1]
# ct_blocks[0] = bit_flip(ct_blocks[0], guess=b'}'[0], flip_pos=15-PADDING_SIZE, padding_byte=position)
# ct_blocks[0] = bit_flip(ct_blocks[0], guess=b'}'[0], flip_pos=15-PADDING_SIZE-2, padding_byte=PADDING_BYTE)
# ct_blocks[0] = bit_flip(ct_blocks[0], guess=b'e'[0], flip_pos=0, padding_byte=PADDING_BYTE)
# ct_blocks[0] = bit_flip(ct_blocks[0], guess=b'{'[0], flip_pos=5, padding_byte=b'\x00'[0])
# ct_blocks[0] = bit_flip(ct_blocks[0], guess=b'e'[0], flip_pos=-15, padding_byte=b'~'[0])
# ct_blocks[0] = bit_flip(ct_blocks[0], guess=13, flip_pos=14, padding_byte=b'b'[0])
# ct_blocks[0] = bit_flip(ct_blocks[0], guess=1, flip_pos=14, padding_byte=b'b'[0])
# ct_blocks[0] = bit_flip(ct_blocks[0], guess=b'_'[0], flip_pos=2, padding_byte=0)
# iv = bit_flip(iv, guess=b'_'[0], flip_pos=15, padding_byte=b'`'[0])
# iv = bit_flip(iv, guess=b'"'[0], flip_pos=1, padding_byte=b'_'[0])

# ct_blocks[-2] = b'0234h678901aac\x2c!'
print(f'ct_blocks: {ct_blocks}')
ct_to_send = b''.join(ct_blocks[1:])
iv = ct_blocks[0]
cipher = AES.new(k, AES.MODE_CBC, iv)
decrypted = cipher.decrypt(ct_to_send)
print(f'decrypted: {get_blocks(decrypted)}')
unpadded = my_unpad(decrypted)
print(f'unpadded: {get_blocks(unpadded)}')
print('_'*50)
# Out:
# b'{"key": "hitcon{a426a426a426a426a426a426a426a426a426a426a426a426_-@0123486759Ab2DeF}"}'
# X: b'}', Y: b'A'
# X: b'}', Y: b'A'
# [b'{"key": "hitcon{', b'a426a426a426a426', b'a426a426a426a426', b'a426a426a426a426', b'_-@0123486759Ab2', b'DeF}"}AAAAAAAAAA']
# ct_blocks: [b'\xef\x17\xbf;\xce\xcd!go\xf0r\x90\x08\xb5\x81+', b'\xa49\xf1\xb2\xd9IJ\xe4u\xbb}\xc3B;\x0e\xc2']
# decrypted: [b'_-@0123486759Ab2']
# pos: -14, Y_ = b'@', Y = b'2'
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/iokernel/code/ctf/hitcon/2023/crypto/careless_padding/dist/sol.ipynb Cell 3 in <cell line: 65>()
#      <a href='vscode-notebook-cell:/home/iokernel/code/ctf/hitcon/2023/crypto/careless_padding/dist/sol.ipynb#W2sZmlsZQ%3D%3D?line=62'>63</a> decrypted = cipher.decrypt(ct_to_send)
#      <a href='vscode-notebook-cell:/home/iokernel/code/ctf/hitcon/2023/crypto/careless_padding/dist/sol.ipynb#W2sZmlsZQ%3D%3D?line=63'>64</a> print(f'decrypted: {get_blocks(decrypted)}')
# ---> <a href='vscode-notebook-cell:/home/iokernel/code/ctf/hitcon/2023/crypto/careless_padding/dist/sol.ipynb#W2sZmlsZQ%3D%3D?line=64'>65</a> unpadded = my_unpad(decrypted)
#      <a href='vscode-notebook-cell:/home/iokernel/code/ctf/hitcon/2023/crypto/careless_padding/dist/sol.ipynb#W2sZmlsZQ%3D%3D?line=65'>66</a> print(f'unpadded: {get_blocks(unpadded)}')
#      <a href='vscode-notebook-cell:/home/iokernel/code/ctf/hitcon/2023/crypto/careless_padding/dist/sol.ipynb#W2sZmlsZQ%3D%3D?line=66'>67</a> print('_'*50)
#
# /home/iokernel/code/ctf/hitcon/2023/crypto/careless_padding/dist/sol.ipynb Cell 3 in my_unpad(message)
#      <a href='vscode-notebook-cell:/home/iokernel/code/ctf/hitcon/2023/crypto/careless_padding/dist/sol.ipynb#W2sZmlsZQ%3D%3D?line=45'>46</a> print(f"pos: {(block_count-2)*N+(X%N)}, Y_ = {bytes([_Y])}, Y = {bytes([Y])}")
#      <a href='vscode-notebook-cell:/home/iokernel/code/ctf/hitcon/2023/crypto/careless_padding/dist/sol.ipynb#W2sZmlsZQ%3D%3D?line=46'>47</a> if (Y != _Y and Y != _Y^1):
# ---> <a href='vscode-notebook-cell:/home/iokernel/code/ctf/hitcon/2023/crypto/careless_padding/dist/sol.ipynb#W2sZmlsZQ%3D%3D?line=47'>48</a>     raise ValueError("Incorrect Padding")
#      <a href='vscode-notebook-cell:/home/iokernel/code/ctf/hitcon/2023/crypto/careless_padding/dist/sol.ipynb#W2sZmlsZQ%3D%3D?line=48'>49</a> return message[:message_len]
#
# ValueError: Incorrect Padding

# %%
import json
#!/usr/local/bin/python
import random
import os
from secret import flag
from Crypto.Cipher import AES
from Crypto.Random import get_random_bytes
import json

N = 16

# 0 -> 0, 1~N -> 1, (N+1)~(2N) -> 2 ...
def count_blocks(length):
    block_count = (length-1) // N + 1
    return block_count

def find_repeat_tail(message):
    Y = message[-1]
    message_len = len(message)
    for i in range(len(message)-1, -1, -1):
        if message[i] != Y:
            X = message[i]
            message_len = i + 1
            break
    return message_len, X, Y

def my_padding(message):
    print(message)
    message_len = len(message)
    block_count = count_blocks(message_len)
    result_len =  block_count * N
    if message_len % N == 0:
        result_len += N
    X = message[-1]
    Y = message[(block_count-2)*N+(X%N)]
    print(f'X: {bytes([X])}, Y: {bytes([Y])}')
    if X==Y:
        Y = Y^1
    print(f'X: {bytes([X])}, Y: {bytes([Y])}')
    padded = message.ljust(result_len, bytes([Y]))
    return padded

def my_unpad(message):
    message_len, X, Y = find_repeat_tail(message)
    block_count = count_blocks(message_len)
    _Y = message[(block_count-2)*N+(X%N)]
    print(f"pos: {(block_count-2)*N+(X%N)}, Y_ = {bytes([_Y])}, Y = {bytes([Y])}")
    if (Y != _Y and Y != _Y^1):
        raise ValueError("Incorrect Padding")
    return message[:message_len]

def get_blocks(data: bytes, bs: int = 16) -> list:
    return [data[i:i+bs] for i in range(0, len(data), bs)]

def bit_flip(previous_block: bytes, guess: int, flip_pos: int, padding_byte: int) -> bytes:
    flipped_byte = bytes([previous_block[flip_pos] ^ guess ^ padding_byte])
    # print(f"previous_block[flip_pos]: {bytes([previous_block[flip_pos]])}")
    return previous_block[:flip_pos] + flipped_byte + previous_block[flip_pos+1:]

k = b'YELLOW SUBMARINE'
iv = b'\x01\x02\x03\x04' * 4
# iv = os.urandom(16)
cipher = AES.new(k, AES.MODE_CBC, iv) 
message = 'hitcon{' + 'a426'*4*3 + '_-@0123486759Ab2DeF}'
message = json.dumps({'key':message}).encode()
padded = my_padding(message)
ciphertext = cipher.encrypt(padded)
print(get_blocks(padded))

# ct_blocks[0] = b'R\xd5\x0bx\xcb\xec\x1b\xf4\xb9k\x84\x07\xa4_\xa3\xb9'
def detect_padding_byte():
    for byte in range(1,256):
        print(f'guessing byte: {bytes([byte])}')
        ct_blocks = get_blocks(ciphertext)[-2:]
        ct_blocks[0] = bit_flip(ct_blocks[0], guess=b'}'[0], flip_pos=15-6, padding_byte=byte)
        # ct_blocks[0] = bytes([96]) + ct_blocks[0][1:]
        # ct_blocks[0] = bit_flip(ct_blocks[0], guess=0, flip_pos=0, padding_byte=1)
        ct_to_send = b''.join(ct_blocks[1:])
        iv = ct_blocks[0]
        cipher = AES.new(k, AES.MODE_CBC, iv)
        decrypted = cipher.decrypt(ct_to_send)
        print(f'decrypted: {get_blocks(decrypted)}')
        try:
            unpadded = my_unpad(decrypted)
            print(f'unpadded: {get_blocks(unpadded)}')
            print('_'*50)
        except:
            print('incorrect padding')
            print('_'*50)
            

# detect_padding_byte()
PADDING_SIZE = 10
PADDING_BYTE = b'A'[0]
# try to get padding byte

# known = b''
# print(f'guessing byte: {bytes([byte])}')
possible_chars = b'2brBR'
for i in possible_chars:
    for character in DICTIONARY:
        try:
            print(f"trying candidate: {bytes([i])}, character: {character}")
            ct_blocks = get_blocks(ciphertext)[-3:-1]
            ct_blocks[0] = bit_flip(ct_blocks[0], guess=i, flip_pos=14, padding_byte=ord(character))
            ct_blocks[0] = bit_flip(ct_blocks[0], guess=b'A'[0], flip_pos=13, padding_byte=14)

            # ct_blocks[-2] = b'0234h678901aac\x2c!'
            # print(f'ct_blocks: {ct_blocks}')
            ct_to_send = b''.join(ct_blocks[1:])
            iv = ct_blocks[0]
            cipher = AES.new(k, AES.MODE_CBC, iv)
            decrypted = cipher.decrypt(ct_to_send)
            unpadded = my_unpad(decrypted)
            print(f'decrypted: {get_blocks(decrypted)}')
            print(f'unpadded: {get_blocks(unpadded)}')

            ct_blocks = get_blocks(ciphertext)[-3:-1]
            ct_blocks[0] = bit_flip(ct_blocks[0], guess=i, flip_pos=14, padding_byte=ord(character))
            ct_blocks[0] = bit_flip(ct_blocks[0], guess=b'A'[0], flip_pos=13, padding_byte=15)
            ct_to_send = b''.join(ct_blocks[1:])
            iv = ct_blocks[0]
            cipher = AES.new(k, AES.MODE_CBC, iv)
            decrypted = cipher.decrypt(ct_to_send)
            unpadded = my_unpad(decrypted)

            print(f'decrypted: {get_blocks(decrypted)}')
            print(f'unpadded: {get_blocks(unpadded)}')
            print('_'*50)
        except:
            pass
# Out:
# b'{"key": "hitcon{a426a426a426a426a426a426a426a426a426a426a426a426_-@0123486759Ab2DeF}"}'
# X: b'}', Y: b'A'
# X: b'}', Y: b'A'
# [b'{"key": "hitcon{', b'a426a426a426a426', b'a426a426a426a426', b'a426a426a426a426', b'_-@0123486759Ab2', b'DeF}"}AAAAAAAAAA']
# trying candidate: b'2', character: a
# pos: -15, Y_ = b'-', Y = b'2'
# trying candidate: b'2', character: b
# pos: -2, Y_ = b'2', Y = b'2'
# decrypted: [b'_-@0123486759\x0e22']
# unpadded: [b'_-@0123486759\x0e']
# pos: -1, Y_ = b'2', Y = b'2'
# decrypted: [b'_-@0123486759\x0f22']
# unpadded: [b'_-@0123486759\x0f']
# __________________________________________________
# trying candidate: b'2', character: c
# pos: -13, Y_ = b'0', Y = b'2'
# trying candidate: b'2', character: d
# pos: -12, Y_ = b'1', Y = b'2'
# trying candidate: b'2', character: e
# pos: -11, Y_ = b'2', Y = b'2'
# decrypted: [b'_-@0123486759\x0e52']
# unpadded: [b'_-@0123486759\x0e5']
# pos: -11, Y_ = b'2', Y = b'2'
# decrypted: [b'_-@0123486759\x0f52']
# unpadded: [b'_-@0123486759\x0f5']
# __________________________________________________
# trying candidate: b'2', character: f
# pos: -10, Y_ = b'3', Y = b'2'
# decrypted: [b'_-@0123486759\x0e62']
# unpadded: [b'_-@0123486759\x0e6']
# pos: -10, Y_ = b'3', Y = b'2'
# decrypted: [b'_-@0123486759\x0f62']
# unpadded: [b'_-@0123486759\x0f6']
# __________________________________________________
# trying candidate: b'2', character: g
# pos: -9, Y_ = b'4', Y = b'2'
# trying candidate: b'2', character: h
# pos: -8, Y_ = b'8', Y = b'2'
# trying candidate: b'2', character: i
# pos: -7, Y_ = b'6', Y = b'2'
# trying candidate: b'2', character: j
# pos: -6, Y_ = b'7', Y = b'2'
# trying candidate: b'2', character: k
# pos: -5, Y_ = b'5', Y = b'2'
# trying candidate: b'2', character: l
# pos: -4, Y_ = b'9', Y = b'2'
# trying candidate: b'2', character: m
# pos: -3, Y_ = b'\x0e', Y = b'2'
# trying candidate: b'2', character: n
# pos: -2, Y_ = b'>', Y = b'2'
# trying candidate: b'2', character: o
# pos: -1, Y_ = b'2', Y = b'2'
# decrypted: [b'_-@0123486759\x0e?2']
# unpadded: [b'_-@0123486759\x0e?']
# pos: -1, Y_ = b'2', Y = b'2'
# decrypted: [b'_-@0123486759\x0f?2']
# unpadded: [b'_-@0123486759\x0f?']
# __________________________________________________
# trying candidate: b'2', character: p
# pos: -16, Y_ = b'_', Y = b'2'
# trying candidate: b'2', character: q
# pos: -15, Y_ = b'-', Y = b'2'
# trying candidate: b'2', character: r
# pos: -14, Y_ = b'@', Y = b'2'
# trying candidate: b'2', character: s
# pos: -13, Y_ = b'0', Y = b'2'
# trying candidate: b'2', character: t
# pos: -12, Y_ = b'1', Y = b'2'
# trying candidate: b'2', character: u
# pos: -11, Y_ = b'2', Y = b'2'
# decrypted: [b'_-@0123486759\x0e%2']
# unpadded: [b'_-@0123486759\x0e%']
# pos: -11, Y_ = b'2', Y = b'2'
# decrypted: [b'_-@0123486759\x0f%2']
# unpadded: [b'_-@0123486759\x0f%']
# __________________________________________________
# trying candidate: b'2', character: v
# pos: -10, Y_ = b'3', Y = b'2'
# decrypted: [b'_-@0123486759\x0e&2']
# unpadded: [b'_-@0123486759\x0e&']
# pos: -10, Y_ = b'3', Y = b'2'
# decrypted: [b'_-@0123486759\x0f&2']
# unpadded: [b'_-@0123486759\x0f&']
# __________________________________________________
# trying candidate: b'2', character: w
# pos: -9, Y_ = b'4', Y = b'2'
# trying candidate: b'2', character: x
# pos: -8, Y_ = b'8', Y = b'2'
# trying candidate: b'2', character: y
# pos: -7, Y_ = b'6', Y = b'2'
# trying candidate: b'2', character: z
# pos: -6, Y_ = b'7', Y = b'2'
# trying candidate: b'2', character: 0
# pos: -16, Y_ = b'_', Y = b'2'
# trying candidate: b'2', character: 1
# pos: -15, Y_ = b'-', Y = b'2'
# trying candidate: b'2', character: 2
# pos: -14, Y_ = b'@', Y = b'2'
# trying candidate: b'2', character: 3
# pos: -13, Y_ = b'0', Y = b'2'
# trying candidate: b'2', character: 4
# pos: -12, Y_ = b'1', Y = b'2'
# trying candidate: b'2', character: 5
# pos: -11, Y_ = b'2', Y = b'2'
# decrypted: [b'_-@0123486759\x0ee2']
# unpadded: [b'_-@0123486759\x0ee']
# pos: -11, Y_ = b'2', Y = b'2'
# decrypted: [b'_-@0123486759\x0fe2']
# unpadded: [b'_-@0123486759\x0fe']
# __________________________________________________
# trying candidate: b'2', character: 6
# pos: -10, Y_ = b'3', Y = b'2'
# decrypted: [b'_-@0123486759\x0ef2']
# unpadded: [b'_-@0123486759\x0ef']
# pos: -10, Y_ = b'3', Y = b'2'
# decrypted: [b'_-@0123486759\x0ff2']
# unpadded: [b'_-@0123486759\x0ff']
# __________________________________________________
# trying candidate: b'2', character: 7
# pos: -9, Y_ = b'4', Y = b'2'
# trying candidate: b'2', character: 8
# pos: -8, Y_ = b'8', Y = b'2'
# trying candidate: b'2', character: 9
# pos: -7, Y_ = b'6', Y = b'2'
# trying candidate: b'2', character: _
# pos: -1, Y_ = b'2', Y = b'2'
# decrypted: [b'_-@0123486759\x0e\x0f2']
# unpadded: [b'_-@0123486759\x0e\x0f']
# pos: -1, Y_ = b'2', Y = b'2'
# decrypted: [b'_-@0123486759\x0f\x0f2']
# unpadded: [b'_-@0123486759\x0f\x0f']
# __________________________________________________
# trying candidate: b'b', character: a
# pos: -15, Y_ = b'-', Y = b'2'
# trying candidate: b'b', character: b
# pos: -14, Y_ = b'@', Y = b'2'
# trying candidate: b'b', character: c
# pos: -13, Y_ = b'0', Y = b'2'
# trying candidate: b'b', character: d
# pos: -12, Y_ = b'1', Y = b'2'
# trying candidate: b'b', character: e
# pos: -11, Y_ = b'2', Y = b'2'
# decrypted: [b'_-@0123486759\x0ee2']
# unpadded: [b'_-@0123486759\x0ee']
# pos: -11, Y_ = b'2', Y = b'2'
# decrypted: [b'_-@0123486759\x0fe2']
# unpadded: [b'_-@0123486759\x0fe']
# __________________________________________________
# trying candidate: b'b', character: f
# pos: -10, Y_ = b'3', Y = b'2'
# decrypted: [b'_-@0123486759\x0ef2']
# unpadded: [b'_-@0123486759\x0ef']
# pos: -10, Y_ = b'3', Y = b'2'
# decrypted: [b'_-@0123486759\x0ff2']
# unpadded: [b'_-@0123486759\x0ff']
# __________________________________________________
# trying candidate: b'b', character: g
# pos: -9, Y_ = b'4', Y = b'2'
# trying candidate: b'b', character: h
# pos: -8, Y_ = b'8', Y = b'2'
# trying candidate: b'b', character: i
# pos: -7, Y_ = b'6', Y = b'2'
# trying candidate: b'b', character: j
# pos: -6, Y_ = b'7', Y = b'2'
# trying candidate: b'b', character: k
# pos: -5, Y_ = b'5', Y = b'2'
# trying candidate: b'b', character: l
# pos: -4, Y_ = b'9', Y = b'2'
# trying candidate: b'b', character: m
# pos: -3, Y_ = b'\x0e', Y = b'2'
# trying candidate: b'b', character: n
# pos: -2, Y_ = b'n', Y = b'2'
# trying candidate: b'b', character: o
# pos: -1, Y_ = b'2', Y = b'2'
# decrypted: [b'_-@0123486759\x0eo2']
# unpadded: [b'_-@0123486759\x0eo']
# pos: -1, Y_ = b'2', Y = b'2'
# decrypted: [b'_-@0123486759\x0fo2']
# unpadded: [b'_-@0123486759\x0fo']
# __________________________________________________
# trying candidate: b'b', character: p
# pos: -16, Y_ = b'_', Y = b'2'
# trying candidate: b'b', character: q
# pos: -15, Y_ = b'-', Y = b'2'
# trying candidate: b'b', character: r
# pos: -14, Y_ = b'@', Y = b'2'
# trying candidate: b'b', character: s
# pos: -13, Y_ = b'0', Y = b'2'
# trying candidate: b'b', character: t
# pos: -12, Y_ = b'1', Y = b'2'
# trying candidate: b'b', character: u
# pos: -11, Y_ = b'2', Y = b'2'
# decrypted: [b'_-@0123486759\x0eu2']
# unpadded: [b'_-@0123486759\x0eu']
# pos: -11, Y_ = b'2', Y = b'2'
# decrypted: [b'_-@0123486759\x0fu2']
# unpadded: [b'_-@0123486759\x0fu']
# __________________________________________________
# trying candidate: b'b', character: v
# pos: -10, Y_ = b'3', Y = b'2'
# decrypted: [b'_-@0123486759\x0ev2']
# unpadded: [b'_-@0123486759\x0ev']
# pos: -10, Y_ = b'3', Y = b'2'
# decrypted: [b'_-@0123486759\x0fv2']
# unpadded: [b'_-@0123486759\x0fv']
# __________________________________________________
# trying candidate: b'b', character: w
# pos: -9, Y_ = b'4', Y = b'2'
# trying candidate: b'b', character: x
# pos: -8, Y_ = b'8', Y = b'2'
# trying candidate: b'b', character: y
# pos: -7, Y_ = b'6', Y = b'2'
# trying candidate: b'b', character: z
# pos: -6, Y_ = b'7', Y = b'2'
# trying candidate: b'b', character: 0
# pos: -16, Y_ = b'_', Y = b'2'
# trying candidate: b'b', character: 1
# pos: -15, Y_ = b'-', Y = b'2'
# trying candidate: b'b', character: 2
# pos: -2, Y_ = b'2', Y = b'2'
# decrypted: [b'_-@0123486759\x0e22']
# unpadded: [b'_-@0123486759\x0e']
# pos: -1, Y_ = b'2', Y = b'2'
# decrypted: [b'_-@0123486759\x0f22']
# unpadded: [b'_-@0123486759\x0f']
# __________________________________________________
# trying candidate: b'b', character: 3
# pos: -13, Y_ = b'0', Y = b'2'
# trying candidate: b'b', character: 4
# pos: -12, Y_ = b'1', Y = b'2'
# trying candidate: b'b', character: 5
# pos: -11, Y_ = b'2', Y = b'2'
# decrypted: [b'_-@0123486759\x0e52']
# unpadded: [b'_-@0123486759\x0e5']
# pos: -11, Y_ = b'2', Y = b'2'
# decrypted: [b'_-@0123486759\x0f52']
# unpadded: [b'_-@0123486759\x0f5']
# __________________________________________________
# trying candidate: b'b', character: 6
# pos: -10, Y_ = b'3', Y = b'2'
# decrypted: [b'_-@0123486759\x0e62']
# unpadded: [b'_-@0123486759\x0e6']
# pos: -10, Y_ = b'3', Y = b'2'
# decrypted: [b'_-@0123486759\x0f62']
# unpadded: [b'_-@0123486759\x0f6']
# __________________________________________________
# trying candidate: b'b', character: 7
# pos: -9, Y_ = b'4', Y = b'2'
# trying candidate: b'b', character: 8
# pos: -8, Y_ = b'8', Y = b'2'
# trying candidate: b'b', character: 9
# pos: -7, Y_ = b'6', Y = b'2'
# trying candidate: b'b', character: _
# pos: -1, Y_ = b'2', Y = b'2'
# decrypted: [b'_-@0123486759\x0e_2']
# unpadded: [b'_-@0123486759\x0e_']
# pos: -1, Y_ = b'2', Y = b'2'
# decrypted: [b'_-@0123486759\x0f_2']
# unpadded: [b'_-@0123486759\x0f_']
# __________________________________________________
# trying candidate: b'r', character: a
# pos: -15, Y_ = b'-', Y = b'2'
# trying candidate: b'r', character: b
# pos: -14, Y_ = b'@', Y = b'2'
# trying candidate: b'r', character: c
# pos: -13, Y_ = b'0', Y = b'2'
# trying candidate: b'r', character: d
# pos: -12, Y_ = b'1', Y = b'2'
# trying candidate: b'r', character: e
# pos: -11, Y_ = b'2', Y = b'2'
# decrypted: [b'_-@0123486759\x0eu2']
# unpadded: [b'_-@0123486759\x0eu']
# pos: -11, Y_ = b'2', Y = b'2'
# decrypted: [b'_-@0123486759\x0fu2']
# unpadded: [b'_-@0123486759\x0fu']
# __________________________________________________
# trying candidate: b'r', character: f
# pos: -10, Y_ = b'3', Y = b'2'
# decrypted: [b'_-@0123486759\x0ev2']
# unpadded: [b'_-@0123486759\x0ev']
# pos: -10, Y_ = b'3', Y = b'2'
# decrypted: [b'_-@0123486759\x0fv2']
# unpadded: [b'_-@0123486759\x0fv']
# __________________________________________________
# trying candidate: b'r', character: g
# pos: -9, Y_ = b'4', Y = b'2'
# trying candidate: b'r', character: h
# pos: -8, Y_ = b'8', Y = b'2'
# trying candidate: b'r', character: i
# pos: -7, Y_ = b'6', Y = b'2'
# trying candidate: b'r', character: j
# pos: -6, Y_ = b'7', Y = b'2'
# trying candidate: b'r', character: k
# pos: -5, Y_ = b'5', Y = b'2'
# trying candidate: b'r', character: l
# pos: -4, Y_ = b'9', Y = b'2'
# trying candidate: b'r', character: m
# pos: -3, Y_ = b'\x0e', Y = b'2'
# trying candidate: b'r', character: n
# pos: -2, Y_ = b'~', Y = b'2'
# trying candidate: b'r', character: o
# pos: -1, Y_ = b'2', Y = b'2'
# decrypted: [b'_-@0123486759\x0e\x7f2']
# unpadded: [b'_-@0123486759\x0e\x7f']
# pos: -1, Y_ = b'2', Y = b'2'
# decrypted: [b'_-@0123486759\x0f\x7f2']
# unpadded: [b'_-@0123486759\x0f\x7f']
# __________________________________________________
# trying candidate: b'r', character: p
# pos: -16, Y_ = b'_', Y = b'2'
# trying candidate: b'r', character: q
# pos: -15, Y_ = b'-', Y = b'2'
# trying candidate: b'r', character: r
# pos: -14, Y_ = b'@', Y = b'2'
# trying candidate: b'r', character: s
# pos: -13, Y_ = b'0', Y = b'2'
# trying candidate: b'r', character: t
# pos: -12, Y_ = b'1', Y = b'2'
# trying candidate: b'r', character: u
# pos: -11, Y_ = b'2', Y = b'2'
# decrypted: [b'_-@0123486759\x0ee2']
# unpadded: [b'_-@0123486759\x0ee']
# pos: -11, Y_ = b'2', Y = b'2'
# decrypted: [b'_-@0123486759\x0fe2']
# unpadded: [b'_-@0123486759\x0fe']
# __________________________________________________
# trying candidate: b'r', character: v
# pos: -10, Y_ = b'3', Y = b'2'
# decrypted: [b'_-@0123486759\x0ef2']
# unpadded: [b'_-@0123486759\x0ef']
# pos: -10, Y_ = b'3', Y = b'2'
# decrypted: [b'_-@0123486759\x0ff2']
# unpadded: [b'_-@0123486759\x0ff']
# __________________________________________________
# trying candidate: b'r', character: w
# pos: -9, Y_ = b'4', Y = b'2'
# trying candidate: b'r', character: x
# pos: -8, Y_ = b'8', Y = b'2'
# trying candidate: b'r', character: y
# pos: -7, Y_ = b'6', Y = b'2'
# trying candidate: b'r', character: z
# pos: -6, Y_ = b'7', Y = b'2'
# trying candidate: b'r', character: 0
# pos: -16, Y_ = b'_', Y = b'2'
# trying candidate: b'r', character: 1
# pos: -15, Y_ = b'-', Y = b'2'
# trying candidate: b'r', character: 2
# pos: -14, Y_ = b'@', Y = b'2'
# trying candidate: b'r', character: 3
# pos: -13, Y_ = b'0', Y = b'2'
# trying candidate: b'r', character: 4
# pos: -12, Y_ = b'1', Y = b'2'
# trying candidate: b'r', character: 5
# pos: -11, Y_ = b'2', Y = b'2'
# decrypted: [b'_-@0123486759\x0e%2']
# unpadded: [b'_-@0123486759\x0e%']
# pos: -11, Y_ = b'2', Y = b'2'
# decrypted: [b'_-@0123486759\x0f%2']
# unpadded: [b'_-@0123486759\x0f%']
# __________________________________________________
# trying candidate: b'r', character: 6
# pos: -10, Y_ = b'3', Y = b'2'
# decrypted: [b'_-@0123486759\x0e&2']
# unpadded: [b'_-@0123486759\x0e&']
# pos: -10, Y_ = b'3', Y = b'2'
# decrypted: [b'_-@0123486759\x0f&2']
# unpadded: [b'_-@0123486759\x0f&']
# __________________________________________________
# trying candidate: b'r', character: 7
# pos: -9, Y_ = b'4', Y = b'2'
# trying candidate: b'r', character: 8
# pos: -8, Y_ = b'8', Y = b'2'
# trying candidate: b'r', character: 9
# pos: -7, Y_ = b'6', Y = b'2'
# trying candidate: b'r', character: _
# pos: -1, Y_ = b'2', Y = b'2'
# decrypted: [b'_-@0123486759\x0eO2']
# unpadded: [b'_-@0123486759\x0eO']
# pos: -1, Y_ = b'2', Y = b'2'
# decrypted: [b'_-@0123486759\x0fO2']
# unpadded: [b'_-@0123486759\x0fO']
# __________________________________________________
# trying candidate: b'B', character: a
# pos: -15, Y_ = b'-', Y = b'2'
# trying candidate: b'B', character: b
# pos: -14, Y_ = b'@', Y = b'2'
# trying candidate: b'B', character: c
# pos: -13, Y_ = b'0', Y = b'2'
# trying candidate: b'B', character: d
# pos: -12, Y_ = b'1', Y = b'2'
# trying candidate: b'B', character: e
# pos: -11, Y_ = b'2', Y = b'2'
# decrypted: [b'_-@0123486759\x0eE2']
# unpadded: [b'_-@0123486759\x0eE']
# pos: -11, Y_ = b'2', Y = b'2'
# decrypted: [b'_-@0123486759\x0fE2']
# unpadded: [b'_-@0123486759\x0fE']
# __________________________________________________
# trying candidate: b'B', character: f
# pos: -10, Y_ = b'3', Y = b'2'
# decrypted: [b'_-@0123486759\x0eF2']
# unpadded: [b'_-@0123486759\x0eF']
# pos: -10, Y_ = b'3', Y = b'2'
# decrypted: [b'_-@0123486759\x0fF2']
# unpadded: [b'_-@0123486759\x0fF']
# __________________________________________________
# trying candidate: b'B', character: g
# pos: -9, Y_ = b'4', Y = b'2'
# trying candidate: b'B', character: h
# pos: -8, Y_ = b'8', Y = b'2'
# trying candidate: b'B', character: i
# pos: -7, Y_ = b'6', Y = b'2'
# trying candidate: b'B', character: j
# pos: -6, Y_ = b'7', Y = b'2'
# trying candidate: b'B', character: k
# pos: -5, Y_ = b'5', Y = b'2'
# trying candidate: b'B', character: l
# pos: -4, Y_ = b'9', Y = b'2'
# trying candidate: b'B', character: m
# pos: -3, Y_ = b'\x0e', Y = b'2'
# trying candidate: b'B', character: n
# pos: -2, Y_ = b'N', Y = b'2'
# trying candidate: b'B', character: o
# pos: -1, Y_ = b'2', Y = b'2'
# decrypted: [b'_-@0123486759\x0eO2']
# unpadded: [b'_-@0123486759\x0eO']
# pos: -1, Y_ = b'2', Y = b'2'
# decrypted: [b'_-@0123486759\x0fO2']
# unpadded: [b'_-@0123486759\x0fO']
# __________________________________________________
# trying candidate: b'B', character: p
# pos: -16, Y_ = b'_', Y = b'2'
# trying candidate: b'B', character: q
# pos: -15, Y_ = b'-', Y = b'2'
# trying candidate: b'B', character: r
# pos: -14, Y_ = b'@', Y = b'2'
# trying candidate: b'B', character: s
# pos: -13, Y_ = b'0', Y = b'2'
# trying candidate: b'B', character: t
# pos: -12, Y_ = b'1', Y = b'2'
# trying candidate: b'B', character: u
# pos: -11, Y_ = b'2', Y = b'2'
# decrypted: [b'_-@0123486759\x0eU2']
# unpadded: [b'_-@0123486759\x0eU']
# pos: -11, Y_ = b'2', Y = b'2'
# decrypted: [b'_-@0123486759\x0fU2']
# unpadded: [b'_-@0123486759\x0fU']
# __________________________________________________
# trying candidate: b'B', character: v
# pos: -10, Y_ = b'3', Y = b'2'
# decrypted: [b'_-@0123486759\x0eV2']
# unpadded: [b'_-@0123486759\x0eV']
# pos: -10, Y_ = b'3', Y = b'2'
# decrypted: [b'_-@0123486759\x0fV2']
# unpadded: [b'_-@0123486759\x0fV']
# __________________________________________________
# trying candidate: b'B', character: w
# pos: -9, Y_ = b'4', Y = b'2'
# trying candidate: b'B', character: x
# pos: -8, Y_ = b'8', Y = b'2'
# trying candidate: b'B', character: y
# pos: -7, Y_ = b'6', Y = b'2'
# trying candidate: b'B', character: z
# pos: -6, Y_ = b'7', Y = b'2'
# trying candidate: b'B', character: 0
# pos: -16, Y_ = b'_', Y = b'2'
# trying candidate: b'B', character: 1
# pos: -15, Y_ = b'-', Y = b'2'
# trying candidate: b'B', character: 2
# pos: -14, Y_ = b'@', Y = b'2'
# trying candidate: b'B', character: 3
# pos: -13, Y_ = b'0', Y = b'2'
# trying candidate: b'B', character: 4
# pos: -12, Y_ = b'1', Y = b'2'
# trying candidate: b'B', character: 5
# pos: -11, Y_ = b'2', Y = b'2'
# decrypted: [b'_-@0123486759\x0e\x152']
# unpadded: [b'_-@0123486759\x0e\x15']
# pos: -11, Y_ = b'2', Y = b'2'
# decrypted: [b'_-@0123486759\x0f\x152']
# unpadded: [b'_-@0123486759\x0f\x15']
# __________________________________________________
# trying candidate: b'B', character: 6
# pos: -10, Y_ = b'3', Y = b'2'
# decrypted: [b'_-@0123486759\x0e\x162']
# unpadded: [b'_-@0123486759\x0e\x16']
# pos: -10, Y_ = b'3', Y = b'2'
# decrypted: [b'_-@0123486759\x0f\x162']
# unpadded: [b'_-@0123486759\x0f\x16']
# __________________________________________________
# trying candidate: b'B', character: 7
# pos: -9, Y_ = b'4', Y = b'2'
# trying candidate: b'B', character: 8
# pos: -8, Y_ = b'8', Y = b'2'
# trying candidate: b'B', character: 9
# pos: -7, Y_ = b'6', Y = b'2'
# trying candidate: b'B', character: _
# pos: -1, Y_ = b'2', Y = b'2'
# decrypted: [b'_-@0123486759\x0e\x7f2']
# unpadded: [b'_-@0123486759\x0e\x7f']
# pos: -1, Y_ = b'2', Y = b'2'
# decrypted: [b'_-@0123486759\x0f\x7f2']
# unpadded: [b'_-@0123486759\x0f\x7f']
# __________________________________________________
# trying candidate: b'R', character: a
# pos: -15, Y_ = b'-', Y = b'2'
# trying candidate: b'R', character: b
# pos: -14, Y_ = b'@', Y = b'2'
# trying candidate: b'R', character: c
# pos: -13, Y_ = b'0', Y = b'2'
# trying candidate: b'R', character: d
# pos: -12, Y_ = b'1', Y = b'2'
# trying candidate: b'R', character: e
# pos: -11, Y_ = b'2', Y = b'2'
# decrypted: [b'_-@0123486759\x0eU2']
# unpadded: [b'_-@0123486759\x0eU']
# pos: -11, Y_ = b'2', Y = b'2'
# decrypted: [b'_-@0123486759\x0fU2']
# unpadded: [b'_-@0123486759\x0fU']
# __________________________________________________
# trying candidate: b'R', character: f
# pos: -10, Y_ = b'3', Y = b'2'
# decrypted: [b'_-@0123486759\x0eV2']
# unpadded: [b'_-@0123486759\x0eV']
# pos: -10, Y_ = b'3', Y = b'2'
# decrypted: [b'_-@0123486759\x0fV2']
# unpadded: [b'_-@0123486759\x0fV']
# __________________________________________________
# trying candidate: b'R', character: g
# pos: -9, Y_ = b'4', Y = b'2'
# trying candidate: b'R', character: h
# pos: -8, Y_ = b'8', Y = b'2'
# trying candidate: b'R', character: i
# pos: -7, Y_ = b'6', Y = b'2'
# trying candidate: b'R', character: j
# pos: -6, Y_ = b'7', Y = b'2'
# trying candidate: b'R', character: k
# pos: -5, Y_ = b'5', Y = b'2'
# trying candidate: b'R', character: l
# pos: -4, Y_ = b'9', Y = b'2'
# trying candidate: b'R', character: m
# pos: -3, Y_ = b'\x0e', Y = b'2'
# trying candidate: b'R', character: n
# pos: -2, Y_ = b'^', Y = b'2'
# trying candidate: b'R', character: o
# pos: -1, Y_ = b'2', Y = b'2'
# decrypted: [b'_-@0123486759\x0e_2']
# unpadded: [b'_-@0123486759\x0e_']
# pos: -1, Y_ = b'2', Y = b'2'
# decrypted: [b'_-@0123486759\x0f_2']
# unpadded: [b'_-@0123486759\x0f_']
# __________________________________________________
# trying candidate: b'R', character: p
# pos: -16, Y_ = b'_', Y = b'2'
# trying candidate: b'R', character: q
# pos: -15, Y_ = b'-', Y = b'2'
# trying candidate: b'R', character: r
# pos: -14, Y_ = b'@', Y = b'2'
# trying candidate: b'R', character: s
# pos: -13, Y_ = b'0', Y = b'2'
# trying candidate: b'R', character: t
# pos: -12, Y_ = b'1', Y = b'2'
# trying candidate: b'R', character: u
# pos: -11, Y_ = b'2', Y = b'2'
# decrypted: [b'_-@0123486759\x0eE2']
# unpadded: [b'_-@0123486759\x0eE']
# pos: -11, Y_ = b'2', Y = b'2'
# decrypted: [b'_-@0123486759\x0fE2']
# unpadded: [b'_-@0123486759\x0fE']
# __________________________________________________
# trying candidate: b'R', character: v
# pos: -10, Y_ = b'3', Y = b'2'
# decrypted: [b'_-@0123486759\x0eF2']
# unpadded: [b'_-@0123486759\x0eF']
# pos: -10, Y_ = b'3', Y = b'2'
# decrypted: [b'_-@0123486759\x0fF2']
# unpadded: [b'_-@0123486759\x0fF']
# __________________________________________________
# trying candidate: b'R', character: w
# pos: -9, Y_ = b'4', Y = b'2'
# trying candidate: b'R', character: x
# pos: -8, Y_ = b'8', Y = b'2'
# trying candidate: b'R', character: y
# pos: -7, Y_ = b'6', Y = b'2'
# trying candidate: b'R', character: z
# pos: -6, Y_ = b'7', Y = b'2'
# trying candidate: b'R', character: 0
# pos: -16, Y_ = b'_', Y = b'2'
# trying candidate: b'R', character: 1
# pos: -15, Y_ = b'-', Y = b'2'
# trying candidate: b'R', character: 2
# pos: -14, Y_ = b'@', Y = b'2'
# trying candidate: b'R', character: 3
# pos: -13, Y_ = b'0', Y = b'2'
# trying candidate: b'R', character: 4
# pos: -12, Y_ = b'1', Y = b'2'
# trying candidate: b'R', character: 5
# pos: -11, Y_ = b'2', Y = b'2'
# decrypted: [b'_-@0123486759\x0e\x052']
# unpadded: [b'_-@0123486759\x0e\x05']
# pos: -11, Y_ = b'2', Y = b'2'
# decrypted: [b'_-@0123486759\x0f\x052']
# unpadded: [b'_-@0123486759\x0f\x05']
# __________________________________________________
# trying candidate: b'R', character: 6
# pos: -10, Y_ = b'3', Y = b'2'
# decrypted: [b'_-@0123486759\x0e\x062']
# unpadded: [b'_-@0123486759\x0e\x06']
# pos: -10, Y_ = b'3', Y = b'2'
# decrypted: [b'_-@0123486759\x0f\x062']
# unpadded: [b'_-@0123486759\x0f\x06']
# __________________________________________________
# trying candidate: b'R', character: 7
# pos: -9, Y_ = b'4', Y = b'2'
# trying candidate: b'R', character: 8
# pos: -8, Y_ = b'8', Y = b'2'
# trying candidate: b'R', character: 9
# pos: -7, Y_ = b'6', Y = b'2'
# trying candidate: b'R', character: _
# pos: -1, Y_ = b'2', Y = b'2'
# decrypted: [b'_-@0123486759\x0eo2']
# unpadded: [b'_-@0123486759\x0eo']
# pos: -1, Y_ = b'2', Y = b'2'
# decrypted: [b'_-@0123486759\x0fo2']
# unpadded: [b'_-@0123486759\x0fo']
# __________________________________________________

# %%
import json
#!/usr/local/bin/python
import random
import os
from secret import flag
from Crypto.Cipher import AES
from Crypto.Random import get_random_bytes
import json

N = 16

# 0 -> 0, 1~N -> 1, (N+1)~(2N) -> 2 ...
def count_blocks(length):
    block_count = (length-1) // N + 1
    return block_count

def find_repeat_tail(message):
    Y = message[-1]
    message_len = len(message)
    for i in range(len(message)-1, -1, -1):
        if message[i] != Y:
            X = message[i]
            message_len = i + 1
            break
    return message_len, X, Y

def my_padding(message):
    print(message)
    message_len = len(message)
    block_count = count_blocks(message_len)
    result_len =  block_count * N
    if message_len % N == 0:
        result_len += N
    X = message[-1]
    Y = message[(block_count-2)*N+(X%N)]
    print(f'X: {bytes([X])}, Y: {bytes([Y])}')
    if X==Y:
        Y = Y^1
    print(f'X: {bytes([X])}, Y: {bytes([Y])}')
    padded = message.ljust(result_len, bytes([Y]))
    return padded

def my_unpad(message):
    message_len, X, Y = find_repeat_tail(message)
    block_count = count_blocks(message_len)
    _Y = message[(block_count-2)*N+(X%N)]
    print(f"pos: {(block_count-2)*N+(X%N)}, Y_ = {bytes([_Y])}, Y = {bytes([Y])}")
    if (Y != _Y and Y != _Y^1):
        raise ValueError("Incorrect Padding")
    return message[:message_len]

def get_blocks(data: bytes, bs: int = 16) -> list:
    return [data[i:i+bs] for i in range(0, len(data), bs)]

def bit_flip(previous_block: bytes, guess: int, flip_pos: int, padding_byte: int) -> bytes:
    flipped_byte = bytes([previous_block[flip_pos] ^ guess ^ padding_byte])
    # print(f"previous_block[flip_pos]: {bytes([previous_block[flip_pos]])}")
    return previous_block[:flip_pos] + flipped_byte + previous_block[flip_pos+1:]

k = b'YELLOW SUBMARINE'
iv = b'\x01\x02\x03\x04' * 4
# iv = os.urandom(16)
cipher = AES.new(k, AES.MODE_CBC, iv) 
message = 'hitcon{this_is_a_really_long_flag_12that_is_very_hard_to_guess_for_testing}'
message = json.dumps({'key':message}).encode()
padded = my_padding(message)
ciphertext = cipher.encrypt(padded)
print(get_blocks(padded))

# try to get padding byte
def get_block_15th_byte_candidates(iv, ciphertexts, known_plaintext):
    candidates = []
    for i in range(16):
        for byte in range(256):
            iv_new = bit_flip(iv, guess=byte, flip_pos=i, padding_byte=0)
            ct_to_send = ciphertexts
            try:
                cipher = AES.new(k, AES.MODE_CBC, iv_new)
                decrypted = cipher.decrypt(ct_to_send)
                print(f'decrypted: {get_blocks(decrypted)}')
                unpadded = my_unpad(decrypted)
                print(f'unpadded: {get_blocks(unpadded)}')
                print('_'*50)
                for character in DICTIONARY:
                    if ord(character) % 16 == i:
                        candidates.append(character)
                last_byte = known_plaintext[i] ^ byte
                return candidates, i, last_byte
            except:
                pass
known_plaintext = b'{"key": "hitcon{'
ct_blocks = get_blocks(ciphertext)
test_ct = b''.join(ct_blocks[:2])
candidates, pos, last_byte = get_block_15th_byte_candidates(iv, test_ct, known_plaintext)
print(f'candidates: {candidates}, pos: {pos}, last_byte: {chr(last_byte)}')

# def get_chars_for_pos(pos: int):
#     candidates = []
#     for character in DICTIONARY:
#         if ord(character)%16 == pos:
#             candidates.append(character)
#     return candidates

# print('#'*50)
# def get_character(iv, ciphertexts, known_plaintext, pos):
#     length_known = len(known_plaintext)
#     iv_new_orig = iv
#     candidates = []
#     iv_new_orig = bit_flip(iv_new_orig, guess=ord(known_plaintext[-1]), flip_pos=15, padding_byte=b'{'[0])
#     # for i in range(15, 15-length_known, -1):
#     #     print(known_plaintext[length_known-(15-i)-1])
#     #     iv_new_orig = bit_flip(iv_new_orig, guess=ord(known_plaintext[length_known-(15-i)-1]), flip_pos=i, padding_byte=b'{'[0])
#     chars_for_pos = get_chars_for_pos(pos)
#     for character in DICTIONARY:
#         print(f"trying character: {character}")
#         iv_new = bit_flip(iv_new_orig, guess=ord(known_plaintext[-2]), flip_pos=14, padding_byte=ord(chars_for_pos[0]))
#         iv_new = bit_flip(iv_new, guess=ord(character), flip_pos=pos, padding_byte=b'{'[0])
#         ct_to_send = ciphertexts
#         try:
#             cipher = AES.new(k, AES.MODE_CBC, iv_new)
#             decrypted = cipher.decrypt(ct_to_send)
#             print(f'decrypted: {get_blocks(decrypted)}')
#             unpadded = my_unpad(decrypted)
#             print(f'unpadded: {get_blocks(unpadded)}')
#             print('_'*50)
#             candidates.append(character)
#         except:
#             pass
#     return candidates
            
# candidates = get_character(test_ct[:16], test_ct[16:], 'lly', 15-len('lly'))
# print(f'candidates: {candidates}')
# ['a', 'c', 'p', 'q', 's', '0', '1', '3']
# candidates: ['a', 'b', 'c', 'f', 'g', 'p', 'q', 'r', 's', 'v', '0', '1', '2', '3', '6']
# Out:
# b'{"key": "hitcon{this_is_a_really_long_flag_12that_is_very_hard_to_guess_for_testing}"}'
# X: b'}', Y: b'e'
# X: b'}', Y: b'e'
# [b'{"key": "hitcon{', b'this_is_a_really', b'_long_flag_12tha', b't_is_very_hard_t', b'o_guess_for_test', b'ing}"}eeeeeeeeee']
# decrypted: [b'{"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'z"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'y"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'x"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\x7f"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'~"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'}"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'|"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b's"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'r"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'q"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'p"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'w"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'v"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'u"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b't"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'k"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'j"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'i"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'h"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'o"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'n"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'm"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'l"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'c"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'b"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'a"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'`"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'g"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'f"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'e"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'd"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'["key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'Z"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'Y"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'X"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'_"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'^"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b']"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\\"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'S"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'R"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'Q"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'P"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'W"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'V"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'U"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'T"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'K"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'J"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'I"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'H"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'O"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'N"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'M"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'L"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'C"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'B"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'A"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'@"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'G"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'F"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'E"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'D"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b';"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b':"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'9"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'8"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'?"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'>"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'="key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'<"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'3"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'2"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'1"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'0"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'7"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'6"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'5"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'4"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'+"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'*"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b')"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'("key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'/"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'."key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'-"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b',"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'#"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'""key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'!"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b' "key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\'"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'&"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'%"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'$"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\x1b"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\x1a"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\x19"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\x18"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\x1f"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\x1e"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\x1d"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\x1c"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\x13"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\x12"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\x11"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\x10"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\x17"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\x16"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\x15"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\x14"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\x0b"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\n"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\t"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\x08"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\x0f"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\x0e"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\r"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\x0c"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\x03"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\x02"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\x01"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\x00"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\x07"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\x06"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\x05"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\x04"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xfb"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xfa"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xf9"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xf8"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xff"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xfe"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xfd"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xfc"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xf3"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xf2"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xf1"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xf0"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xf7"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xf6"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xf5"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xf4"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xeb"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xea"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xe9"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xe8"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xef"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xee"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xed"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xec"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xe3"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xe2"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xe1"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xe0"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xe7"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xe6"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xe5"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xe4"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xdb"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xda"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xd9"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xd8"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xdf"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xde"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xdd"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xdc"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xd3"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xd2"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xd1"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xd0"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xd7"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xd6"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xd5"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xd4"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xcb"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xca"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xc9"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xc8"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xcf"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xce"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xcd"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xcc"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xc3"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xc2"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xc1"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xc0"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xc7"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xc6"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xc5"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xc4"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xbb"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xba"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xb9"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xb8"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xbf"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xbe"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xbd"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xbc"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xb3"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xb2"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xb1"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xb0"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xb7"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xb6"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xb5"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xb4"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xab"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xaa"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xa9"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xa8"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xaf"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xae"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xad"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xac"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xa3"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xa2"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xa1"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xa0"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xa7"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xa6"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xa5"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\xa4"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\x9b"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\x9a"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\x99"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\x98"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\x9f"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\x9e"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\x9d"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\x9c"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\x93"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\x92"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\x91"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\x90"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\x97"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\x96"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\x95"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\x94"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\x8b"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\x8a"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\x89"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\x88"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\x8f"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\x8e"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\x8d"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\x8c"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\x83"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\x82"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\x81"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\x80"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\x87"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\x86"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\x85"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'\x84"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{#key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{ key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{!key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{&key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\'key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{$key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{%key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{*key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{+key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{(key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{)key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{.key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{/key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{,key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{-key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{2key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{3key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{0key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{1key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{6key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{7key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{4key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{5key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{:key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{;key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{8key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{9key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{>key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{?key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{<key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{=key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\x02key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\x03key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\x00key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\x01key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\x06key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\x07key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\x04key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\x05key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\nkey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\x0bkey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\x08key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\tkey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\x0ekey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\x0fkey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\x0ckey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\rkey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\x12key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\x13key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\x10key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\x11key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\x16key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\x17key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\x14key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\x15key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\x1akey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\x1bkey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\x18key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\x19key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\x1ekey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\x1fkey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\x1ckey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\x1dkey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{bkey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{ckey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{`key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{akey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{fkey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{gkey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{dkey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{ekey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{jkey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{kkey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{hkey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{ikey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{nkey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{okey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{lkey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{mkey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{rkey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{skey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{pkey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{qkey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{vkey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{wkey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{tkey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{ukey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{zkey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{{key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{xkey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{ykey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{~key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\x7fkey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{|key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{}key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{Bkey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{Ckey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{@key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{Akey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{Fkey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{Gkey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{Dkey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{Ekey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{Jkey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{Kkey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{Hkey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{Ikey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{Nkey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{Okey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{Lkey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{Mkey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{Rkey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{Skey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{Pkey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{Qkey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{Vkey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{Wkey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{Tkey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{Ukey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{Zkey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{[key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{Xkey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{Ykey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{^key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{_key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\\key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{]key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xa2key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xa3key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xa0key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xa1key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xa6key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xa7key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xa4key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xa5key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xaakey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xabkey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xa8key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xa9key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xaekey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xafkey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xackey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xadkey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xb2key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xb3key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xb0key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xb1key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xb6key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xb7key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xb4key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xb5key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xbakey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xbbkey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xb8key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xb9key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xbekey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xbfkey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xbckey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xbdkey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\x82key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\x83key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\x80key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\x81key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\x86key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\x87key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\x84key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\x85key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\x8akey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\x8bkey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\x88key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\x89key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\x8ekey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\x8fkey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\x8ckey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\x8dkey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\x92key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\x93key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\x90key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\x91key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\x96key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\x97key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\x94key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\x95key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\x9akey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\x9bkey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\x98key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\x99key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\x9ekey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\x9fkey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\x9ckey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\x9dkey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xe2key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xe3key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xe0key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xe1key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xe6key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xe7key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xe4key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xe5key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xeakey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xebkey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xe8key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xe9key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xeekey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xefkey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xeckey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xedkey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xf2key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xf3key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xf0key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xf1key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xf6key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xf7key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xf4key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xf5key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xfakey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xfbkey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xf8key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xf9key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xfekey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xffkey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xfckey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xfdkey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xc2key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xc3key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xc0key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xc1key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xc6key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xc7key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xc4key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xc5key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xcakey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xcbkey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xc8key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xc9key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xcekey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xcfkey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xcckey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xcdkey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xd2key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xd3key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xd0key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xd1key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xd6key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xd7key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xd4key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xd5key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xdakey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xdbkey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xd8key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xd9key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xdekey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xdfkey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xdckey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{\xddkey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"jey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"iey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"hey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"oey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"ney": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"mey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"ley": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"cey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"bey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"aey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"`ey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"gey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"fey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"eey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"dey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"{ey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"zey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"yey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"xey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"\x7fey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"~ey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"}ey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"|ey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"sey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"rey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"qey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"pey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"wey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"vey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"uey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"tey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"Key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"Jey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"Iey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"Hey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"Oey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"Ney": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"Mey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"Ley": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"Cey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"Bey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"Aey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"@ey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"Gey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"Fey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"Eey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"Dey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"[ey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"Zey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"Yey": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"Xey": "hitcon{', b'this_is_a_really']
# ...
# decrypted: [b'{"key": "hi\x16con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\x17con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\x10con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\x11con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\x12con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\x13con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\x1ccon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\x1dcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\x1econ{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\x1fcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\x18con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\x19con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\x1acon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\x1bcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\x04con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\x05con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\x06con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\x07con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\x00con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\x01con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\x02con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\x03con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\x0ccon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\rcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\x0econ{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\x0fcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\x08con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\tcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\ncon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\x0bcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xf4con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xf5con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xf6con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xf7con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xf0con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xf1con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xf2con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xf3con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xfccon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xfdcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xfecon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xffcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xf8con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xf9con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xfacon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xfbcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xe4con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xe5con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xe6con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xe7con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xe0con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xe1con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xe2con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xe3con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xeccon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xedcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xeecon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xefcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xe8con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xe9con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xeacon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xebcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xd4con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xd5con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xd6con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xd7con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xd0con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xd1con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xd2con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xd3con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xdccon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xddcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xdecon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xdfcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xd8con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xd9con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xdacon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xdbcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xc4con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xc5con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xc6con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xc7con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xc0con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xc1con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xc2con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xc3con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xcccon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xcdcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xcecon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xcfcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xc8con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xc9con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xcacon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xcbcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xb4con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xb5con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xb6con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xb7con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xb0con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xb1con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xb2con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xb3con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xbccon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xbdcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xbecon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xbfcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xb8con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xb9con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xbacon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xbbcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xa4con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xa5con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xa6con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xa7con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xa0con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xa1con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xa2con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xa3con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xaccon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xadcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xaecon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xafcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xa8con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xa9con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xaacon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\xabcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\x94con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\x95con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\x96con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\x97con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\x90con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\x91con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\x92con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\x93con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\x9ccon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\x9dcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\x9econ{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\x9fcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\x98con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\x99con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\x9acon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\x9bcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\x84con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\x85con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\x86con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\x87con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\x80con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\x81con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\x82con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\x83con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\x8ccon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\x8dcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\x8econ{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\x8fcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\x88con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\x89con{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\x8acon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hi\x8bcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hitcon{', b'this_is_a_really']
# pos: 12, Y_ = b'c', Y = b'y'
# decrypted: [b'{"key": "hitbon{', b'this_is_a_really']
# pos: 12, Y_ = b'b', Y = b'y'
# decrypted: [b'{"key": "hitaon{', b'this_is_a_really']
# pos: 12, Y_ = b'a', Y = b'y'
# decrypted: [b'{"key": "hit`on{', b'this_is_a_really']
# pos: 12, Y_ = b'`', Y = b'y'
# decrypted: [b'{"key": "hitgon{', b'this_is_a_really']
# pos: 12, Y_ = b'g', Y = b'y'
# decrypted: [b'{"key": "hitfon{', b'this_is_a_really']
# pos: 12, Y_ = b'f', Y = b'y'
# decrypted: [b'{"key": "hiteon{', b'this_is_a_really']
# pos: 12, Y_ = b'e', Y = b'y'
# decrypted: [b'{"key": "hitdon{', b'this_is_a_really']
# pos: 12, Y_ = b'd', Y = b'y'
# decrypted: [b'{"key": "hitkon{', b'this_is_a_really']
# pos: 12, Y_ = b'k', Y = b'y'
# decrypted: [b'{"key": "hitjon{', b'this_is_a_really']
# pos: 12, Y_ = b'j', Y = b'y'
# decrypted: [b'{"key": "hition{', b'this_is_a_really']
# pos: 12, Y_ = b'i', Y = b'y'
# decrypted: [b'{"key": "hithon{', b'this_is_a_really']
# pos: 12, Y_ = b'h', Y = b'y'
# decrypted: [b'{"key": "hitoon{', b'this_is_a_really']
# pos: 12, Y_ = b'o', Y = b'y'
# decrypted: [b'{"key": "hitnon{', b'this_is_a_really']
# pos: 12, Y_ = b'n', Y = b'y'
# decrypted: [b'{"key": "hitmon{', b'this_is_a_really']
# pos: 12, Y_ = b'm', Y = b'y'
# decrypted: [b'{"key": "hitlon{', b'this_is_a_really']
# pos: 12, Y_ = b'l', Y = b'y'
# decrypted: [b'{"key": "hitson{', b'this_is_a_really']
# pos: 12, Y_ = b's', Y = b'y'
# decrypted: [b'{"key": "hitron{', b'this_is_a_really']
# pos: 12, Y_ = b'r', Y = b'y'
# decrypted: [b'{"key": "hitqon{', b'this_is_a_really']
# pos: 12, Y_ = b'q', Y = b'y'
# decrypted: [b'{"key": "hitpon{', b'this_is_a_really']
# pos: 12, Y_ = b'p', Y = b'y'
# decrypted: [b'{"key": "hitwon{', b'this_is_a_really']
# pos: 12, Y_ = b'w', Y = b'y'
# decrypted: [b'{"key": "hitvon{', b'this_is_a_really']
# pos: 12, Y_ = b'v', Y = b'y'
# decrypted: [b'{"key": "hituon{', b'this_is_a_really']
# pos: 12, Y_ = b'u', Y = b'y'
# decrypted: [b'{"key": "hitton{', b'this_is_a_really']
# pos: 12, Y_ = b't', Y = b'y'
# decrypted: [b'{"key": "hit{on{', b'this_is_a_really']
# pos: 12, Y_ = b'{', Y = b'y'
# decrypted: [b'{"key": "hitzon{', b'this_is_a_really']
# pos: 12, Y_ = b'z', Y = b'y'
# decrypted: [b'{"key": "hityon{', b'this_is_a_really']
# pos: 12, Y_ = b'y', Y = b'y'
# unpadded: [b'{"key": "hityon{', b'this_is_a_reall']
# __________________________________________________
# candidates: ['l', 'L'], pos: 12, last_byte: y

# %%
def get_chars_for_pos(pos: int):
    candidates = []
    for character in DICTIONARY:
        if ord(character)%16 == pos:
            candidates.append(character)
    return candidates

get_chars_for_pos(13)
# Out:
# ['m']

# %%
# we know X % 16 = 2
from string import printable

for character in printable:
    if ord(character)%16 == 2:
        print(character, end='')
# Out:
# 2brBR"

# %%
chr(b'{'[0] ^ 1)
# Out:
# 'z'
